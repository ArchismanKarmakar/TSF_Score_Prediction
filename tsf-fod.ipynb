# %% [markdown]
# **Prediction Using Supervised ML**
#
# Prediction of the precentage of an student based on the no. of study hours
#
# TSF Task 1

# %% [markdown]
# Author: **Archisman Karmakar**
#
# **A simple linear regression task involving two variables**

# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
#displaying the data from the given link
url = "http://bit.ly/w-data"
data = pd.read_csv(url)
data
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %% [markdown]
# **Evaluating the given dataset**

# %%
data.shape #checking the shape of the dataset
# Out:
# (25, 2)

# %%
data.dtypes  #checking the data types of the dataset
# Out:
# Hours     float64
# Scores      int64
# dtype: object

# %%
data.isnull()  #checking presence of NULL values
# Out:
#     Hours  Scores
# 0   False   False
# 1   False   False
# 2   False   False
# 3   False   False
# 4   False   False
# 5   False   False
# 6   False   False
# 7   False   False
# 8   False   False
# 9   False   False
# 10  False   False
# 11  False   False
# 12  False   False
# 13  False   False
# 14  False   False
# 15  False   False
# 16  False   False
# 17  False   False
# 18  False   False
# 19  False   False
# 20  False   False
# 21  False   False
# 22  False   False
# 23  False   False
# 24  False   False

# %%
data.describe()  #checking the mean,std etc of give dataset
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %% [markdown]
# **Scatter plot of given 2 variables**

# %%
X = data['Hours']
Y = data['Scores']
plt.scatter(X,Y)
plt.title('Hours vs Score')
plt.xlabel('Hours studied')
plt.ylabel('Score (in %age)')
plt.show()

# %% [markdown]
# **Dividing the data into "attributes" and "labels"**

# %%
X = data.iloc[:, :-1].values  
y = data.iloc[:, 1].values
# print(X,y)

# %% [markdown]
# **Splitting the data into training and test sets**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y,test_size=0.2, random_state=0)
# print(X_train, X_test, Y_train, Y_test)

# %% [markdown]
# **Evalutation of train and test sets**

# %%
print(len(X_train),len(Y_train))
# Out:
# 20 20

# %%
print(len(X_test),len(Y_test))
# Out:
# 5 5

# %% [markdown]
# **Training the data set**

# %%
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Showing the intercept and coefficient of the regression line**

# %%
print(model.intercept_,model.coef_)
# Out:
# 2.018160041434662 [9.91065648]

# %% [markdown]
# **Plotting the regression line**

# %%
line = model.coef_*X + model.intercept_
plt.scatter(X, y)
plt.plot(X, line);
plt.show()

# %% [markdown]
# **Printing the test data set**

# %%
print(X_test)
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %% [markdown]
# **Doing prediction based on the test data set & displaying actual and predicted result**

# %%
Y_pred = model.predict(X_test)
df = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})  
df
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %% [markdown]
# **Predicting score based on a given input**

# %%
hours = 9.25
prediction = model.predict([[hours]])
print("Number of Hours studied: = {}".format(hours))
print("Predicted Score according to our model: = {}".format(prediction[0]))
# Out:
# Number of Hours studied: = 9.25
# Predicted Score according to our model: = 93.69173248737539

# %% [markdown]
# **Determining the mean absolute error (MSE) of our ML model:**

# %%
print("Mean Absolute Error of our model is: ", metrics.mean_absolute_error(Y_test,Y_pred))
# Out:
# Mean Absolute Error of our model is:  4.183859899002982
